# %%
import pandas as pd
personas = pd.read_csv("personas_2011.csv", sep=";")

# %%
personas["seniority_level"].astype("string")
personas.info()

# %%
# metodo para filtrar en columnas de tipo str
personas[personas["seniority_level"].str.contains("A")]
personas[personas["seniority_level"].str.contains("A")].count()
personas[personas["seniority_level"].str.contains("A")].head()
# Out:
#     persona_id  anio  sexo_id  edad  maximo_grado_academico_id  \
# 9           19  2011        2    52                          1
# 12          23  2011        2    58                          1
# 15          26  2011        1    60                          1
# 16          27  2011        1    51                          5
# 19          32  2011        1    47                          1
#
#     disciplina_maximo_grado_academico_id  disciplina_titulo_grado_id  \
# 9                                    255                         255
# 12                                   256                         256
# 15                                   251                         251
# 16                                   207                         207
# 19                                   106                          38
#
#     disciplina_experticia_id  tipo_personal_id  producciones_ult_anio  ...  \
# 9                        255                 3                      0  ...
# ...

# %%
personas.loc[19, "seniority_level"]
# Out:
# 'A  '

# %%
# concatenar df
import pandas as pd
personas = pd.read_csv("personas_2011.csv", sep=";")
categoria_a = personas[personas["seniority_level"].str.contains("A")]
categoria_b = personas[personas["seniority_level"].str.contains("B")]
pd.concat([categoria_a, categoria_b])
